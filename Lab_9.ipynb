# %% [markdown]
# <a href="https://colab.research.google.com/github/241b215-Rupesh/APS-LAB/blob/main/Lab_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Shortest Path Using Dijkstra Algorithm in Python
# Problem Description:
# Given a weighted graph with non negative edge weights. Find the shortest distance from a source vertex to all other vertices using Dijkstra algorithm

# %% [markdown]
# #Theory
# Dijkstra algorithm finds shortest distance from one source node to all other nodes in a weighted graph with non negative weights. Dictionary structure stores nodes as keys and neighbor nodes with weights as values.
#
# ##Algorithm Steps
#
# 1. Represent graph using dictionary.
# 2. Set distance of every node as infinity.
# 3. Set distance of source node as 0.
# 4. Select node with smallest distance among unvisited nodes.
# 5. Update distance of neighbor nodes.
# 6. Repeat until all nodes get visited.

# %%
def dijkstra(graph, start):

    distances = {}
    visited = []

    for node in graph:
        distances[node] = float('inf')

    distances[start] = 0

    while len(visited) < len(graph):

        min_node = None
        min_distance = float('inf')

        for node in graph:
            if node not in visited and distances[node] < min_distance:
                min_distance = distances[node]
                min_node = node

        visited.append(min_node)

        for neighbor, weight in graph[min_node].items():
            new_distance = distances[min_node] + weight

            if new_distance < distances[neighbor]:
                distances[neighbor] = new_distance

    return distances

# %%
graph = {
'A': {'B': 4, 'C': 2},
'B': {'A': 4, 'C': 5, 'D': 10},
'C': {'A': 2, 'B': 5, 'D': 3},
'D': {'B': 10, 'C': 3}
}

result = dijkstra(graph, 'A')

for node in result:
    print("Distance from A to", node, "=", result[node])
# Out:
# Distance from A to A = 0
# Distance from A to B = 4
# Distance from A to C = 2
# Distance from A to D = 5

# %% [markdown]
# Now, let's implement
# 1. Modify program for user input graph using dictionary.
# 2. Display shortest path with total distance.
# 3. Add two more nodes in graph.
# 4. Test algorithm with different source nodes.

# %%
def dijkstra(graph, start):

    distances = {}
    visited = []
    previous = {}

    for node in graph:
        distances[node] = float('inf')
        previous[node] = None

    distances[start] = 0

    while len(visited) < len(graph):

        min_node = None
        min_distance = float('inf')

        for node in graph:
            if node not in visited and distances[node] < min_distance:
                min_distance = distances[node]
                min_node = node

        if min_node is None:
            break

        visited.append(min_node)

        for neighbor, weight in graph[min_node].items():
            new_distance = distances[min_node] + weight

            if new_distance < distances[neighbor]:
                distances[neighbor] = new_distance
                previous[neighbor] = min_node

    return distances, previous

graph = {}

n = int(input("Enter number of nodes: "))

for _ in range(n):
    node = input("Enter node name: ")
    graph[node] = {}

    neighbors = int(input(f"Enter number of neighbors for {node}: "))
    for _ in range(neighbors):
        neigh, wt = input("Enter neighbor and weight: ").split()
        graph[node][neigh] = int(wt)

print("Adding two extra nodes: X and Y")
graph['X'] = {'A': 3}
graph['Y'] = {'X': 2}

while True:
    start = input("Enter start or exit: ")
    if start == 'exit':
        break

    if start not in graph:
        print("Invalid node!")
        continue

    distances, previous = dijkstra(graph, start)

    print("\nShortest paths from", start)

    for node in graph:
        path = []
        current = node

        while current is not None:
            path.append(current)
            current = previous[current]

        path.reverse()

        print(f"{start} -> {node} = {distances[node]}, Path: {' -> '.join(path)}")
# Out:
# Enter number of nodes: 2
# Enter node name: a
# Enter number of neighbors for a: 3
# Enter neighbor and weight: b 5
# Enter neighbor and weight: c 2
# Enter neighbor and weight: d 6
# Enter node name: d 2
# Enter number of neighbors for d 2: a 3
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_6938/2659703207.py in <cell line: 0>()
#      43     graph[node] = {}
#      44
# ---> 45     neighbors = int(input(f"Enter number of neighbors for {node}: "))
#      46     for _ in range(neighbors):
#      47         neigh, wt = input("Enter neighbor and weight: ").split()
#
# ValueError: invalid literal for int() with base 10: 'a 3'
